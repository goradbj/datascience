# %% [markdown]
# #### pandas
# - pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
# - Python with Pandas is used in a wide range of fields including academic and commercial domains including finance, economics, Statistics, analytics, etc.
# - Panel Data – an Econometrics from Multidimensional data.
# - In 2008, developer Wes McKinney started developing pandas when in need of high performance, flexible tool for analysis of data.

# %%
pip show pandas
# Out:
# Name: pandas
# Version: 0.23.4
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: http://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages
# Requires: python-dateutil, numpy, pytz
# Required-by: seaborn
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
weather_data={
    "day":["1/1/2020",'1/2/2020','1/3/2020','1/4/2020','1/5/2020','1/6/2020'],
    "temp":[34,23,41,38,28,19],
    'windspeed':[12,18,17,38,22,23],
    'event':['sunny','rain','overcast','sunny','rain','snow']
}

# %%
weather_data
# Out:
# {'day': ['1/1/2020',
#   '1/2/2020',
#   '1/3/2020',
#   '1/4/2020',
#   '1/5/2020',
#   '1/6/2020'],
#  'temp': [34, 23, 41, 38, 28, 19],
#  'windspeed': [12, 18, 17, 38, 22, 23],
#  'event': ['sunny', 'rain', 'overcast', 'sunny', 'rain', 'snow']}

# %% [markdown]
# ##### Creating Dataframe from dictionary i.e Python Object

# %%
df=pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temp  windspeed     event
# 0  1/1/2020    34         12     sunny
# 1  1/2/2020    23         18      rain
# 2  1/3/2020    41         17  overcast
# 3  1/4/2020    38         38     sunny
# 4  1/5/2020    28         22      rain
# 5  1/6/2020    19         23      snow

# %%
df.columns
# Out:
# Index(['day', 'temp', 'windspeed', 'event'], dtype='object')

# %%
df.shape
# Out:
# (6, 4)

# %%
df.size
# Out:
# 24

# %%
df.head(2)
# Out:
#         day  temp  windspeed  event
# 0  1/1/2020    34         12  sunny
# 1  1/2/2020    23         18   rain

# %%
df.tail(2)
# Out:
#         day  temp  windspeed event
# 4  1/5/2020    28         22  rain
# 5  1/6/2020    19         23  snow

# %%
df1=df[2:4]
df1
# Out:
#         day  temp  windspeed     event
# 2  1/3/2020    41         17  overcast
# 3  1/4/2020    38         38     sunny

# %%
df1.shape
# Out:
# (2, 4)

# %%
df
# Out:
#         day  temp  windspeed     event
# 0  1/1/2020    34         12     sunny
# 1  1/2/2020    23         18      rain
# 2  1/3/2020    41         17  overcast
# 3  1/4/2020    38         38     sunny
# 4  1/5/2020    28         22      rain
# 5  1/6/2020    19         23      snow

# %%
# how to select specific Columns
new_df=df[['day','event']]

# %%
new_df
# Out:
#         day     event
# 0  1/1/2020     sunny
# 1  1/2/2020      rain
# 2  1/3/2020  overcast
# 3  1/4/2020     sunny
# 4  1/5/2020      rain
# 5  1/6/2020      snow

# %%
# how to see values from specific column
df['day']
# Out:
# 0    1/1/2020
# 1    1/2/2020
# 2    1/3/2020
# 3    1/4/2020
# 4    1/5/2020
# 5    1/6/2020
# Name: day, dtype: object

# %%
df2=df['windspeed']

# %%
df2
# Out:
# 0    12
# 1    18
# 2    17
# 3    38
# 4    22
# 5    23
# Name: windspeed, dtype: int64

# %%
df2.max()
# Out:
# 38

# %%
df2.min()
# Out:
# 12

# %%
df2.mean()
# Out:
# 21.666666666666668

# %%
df
# Out:
#         day  temp  windspeed     event
# 0  1/1/2020    34         12     sunny
# 1  1/2/2020    23         18      rain
# 2  1/3/2020    41         17  overcast
# 3  1/4/2020    38         38     sunny
# 4  1/5/2020    28         22      rain
# 5  1/6/2020    19         23      snow

# %%
# Display records where temp is greater than 35 - Just like SQL Statements
high_temp=df[df['temp']>35]
high_temp
# Out:
#         day  temp  windspeed     event
# 2  1/3/2020    41         17  overcast
# 3  1/4/2020    38         38     sunny

# %%
# Display day where temp is less than 35 - Just like SQL Statements
low_temp=df['day'][df['temp']<20]
low_temp
# Out:
# 5    1/6/2020
# Name: day, dtype: object

# %% [markdown]
# #### find mean, Median  and Mode, standard Deviation

# %%
df
# Out:
#         day  temp  windspeed     event
# 0  1/1/2020    34         12     sunny
# 1  1/2/2020    23         18      rain
# 2  1/3/2020    41         17  overcast
# 3  1/4/2020    38         38     sunny
# 4  1/5/2020    28         22      rain
# 5  1/6/2020    19         23      snow

# %%
df.temp.mean()
# Out:
# 30.5

# %%
df.temp.median()
# Out:
# 31.0

# %%
df.temp.mode()
# Out:
# 0    19
# 1    23
# 2    28
# 3    34
# 4    38
# 5    41
# dtype: int64

# %%
df.temp.std()
# Out:
# 8.64291617453276

# %% [markdown]
# #### How to read data from CSV file -

# %%
df=pd.read_csv("C:/Users/Administrator/Desktop/pythoncc/datasets/Road_Accidents_2017-Annexure_ Tables_1.csv")

# %%
df
# Out:
#     Years  Total Number of Road Accidents (in numbers)  \
# 0    1970                                       114100
# 1    1980                                       153200
# 2    1990                                       282600
# 3    1994                                       325864
# 4    1995                                       351999
# 5    1996                                       371204
# 6    1997                                       373671
# 7    1998                                       385018
# 8    1999                                       386456
# 9    2000                                       391449
# 10   2001                                       405637
# 11   2002                                       407497
# 12   2003                                       406726
# 13   2004                                       429910
# 14   2005                                       439255
# 15   2006                                       460920
# ...

# %%
newdf=df[['Years','Total Number of Persons Killed (in numbers)']]

# %%
newdf
# Out:
#     Years  Total Number of Persons Killed (in numbers)
# 0    1970                                        14500
# 1    1980                                        24000
# 2    1990                                        54100
# 3    1994                                        64463
# 4    1995                                        70781
# 5    1996                                        74665
# 6    1997                                        76977
# 7    1998                                        79919
# 8    1999                                        81966
# 9    2000                                        78911
# 10   2001                                        80888
# 11   2002                                        84674
# 12   2003                                        85998
# 13   2004                                        92618
# 14   2005                                        94968
# 15   2006                                       105749
# ...

# %%
# find 
newdf.describe()
# Out:
#              Years  Total Number of Persons Killed (in numbers)
# count    27.000000                                    27.000000
# mean   2002.666667                                 98610.037037
# std      10.891069                                 37324.713290
# min    1970.000000                                 14500.000000
# 25%    1997.500000                                 77944.000000
# 50%    2004.000000                                 92618.000000
# 75%    2010.500000                                136042.500000
# max    2017.000000                                150785.000000

# %%
newdf.isnull()
# Out:
#     Years  Total Number of Persons Killed (in numbers)
# 0   False                                        False
# 1   False                                        False
# 2   False                                        False
# 3   False                                        False
# 4   False                                        False
# 5   False                                        False
# 6   False                                        False
# 7   False                                        False
# 8   False                                        False
# 9   False                                        False
# 10  False                                        False
# 11  False                                        False
# 12  False                                        False
# 13  False                                        False
# 14  False                                        False
# 15  False                                        False
# ...

# %%
df
# Out:
#     Years  Total Number of Road Accidents (in numbers)  \
# 0    1970                                       114100
# 1    1980                                       153200
# 2    1990                                       282600
# 3    1994                                       325864
# 4    1995                                       351999
# 5    1996                                       371204
# 6    1997                                       373671
# 7    1998                                       385018
# 8    1999                                       386456
# 9    2000                                       391449
# 10   2001                                       405637
# 11   2002                                       407497
# 12   2003                                       406726
# 13   2004                                       429910
# 14   2005                                       439255
# 15   2006                                       460920
# ...

# %%
df.isnull()
# Out:
#     Years  Total Number of Road Accidents (in numbers)  \
# 0   False                                        False
# 1   False                                        False
# 2   False                                        False
# 3   False                                        False
# 4   False                                        False
# 5   False                                        False
# 6   False                                        False
# 7   False                                        False
# 8   False                                        False
# 9   False                                        False
# 10  False                                        False
# 11  False                                        False
# 12  False                                        False
# 13  False                                        False
# 14  False                                        False
# 15  False                                        False
# ...

# %%
df.isnull().sum()
# Out:
# Years                                                       0
# Total Number of Road Accidents (in numbers)                 0
# Total Number of Persons Killed (in numbers)                 0
# Total Number of Persons Injured (in numbers)                0
# Population of India (in thousands)                          0
# Total Number of Registered Motor Vehicles (in thousands)    1
# Road Length (in kms)                                        1
# Number of Accidents per Lakh Population                     0
# Number of Accidents per Ten Thousand Vehicles               1
# Number of Accidents per Ten Thousand Kms of Roads           1
# Number of Persons Killed Per Lakh Population                0
# Number of Persons Killed Per Ten Thousand Vehicles          1
# Number of Persons Killed per Ten Thousand Kms of Roads      1
# Number of Persons Injured per Lakh Population               0
# Number of Persons Injured Per Ten Thousand Vehicles         1
# ...

# %%
newdf.isnull().sum()
# Out:
# Years                                          0
# Total Number of Persons Killed (in numbers)    0
# dtype: int64

# %%
df[['Road Length (in kms)']].isnull().sum()
# Out:
# Road Length (in kms)    1
# dtype: int64

# %% [markdown]
# ### How to handle Missing Values

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Administrator/Desktop/pythoncc/datasets/weather_data1.csv")

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.isnull()
# Out:
#      day  temperature  windspeed  event
# 0  False        False      False  False
# 1  False         True      False  False
# 2  False        False       True  False
# 3  False         True      False   True
# 4  False        False       True  False
# 5  False         True       True  False
# 6  False         True       True   True
# 7  False        False      False  False
# 8  False        False      False  False

# %%
df.isnull().sum()
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
type(df.day[0])
# Out:
# str

# %%
type(df.temperature[0])
# Out:
# numpy.float64

# %%
type(df.windspeed[0])
# Out:
# numpy.float64

# %%
type(df.event[0])
# Out:
# str

# %%
df=pd.read_csv("C:/Users/Administrator/Desktop/pythoncc/datasets/weather_data1.csv",parse_dates=['day'])

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf=df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':"NO Event"
})

# %%
newdf
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  NO Event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  NO Event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
ff_data=df.fillna(method="ffill")
ff_data
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
bf_data=df.fillna(method="bfill")
bf_data
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
ip_data=df.interpolate()
ip_data
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
ip1_data=df.interpolate(method='time')
ip1_data
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny
